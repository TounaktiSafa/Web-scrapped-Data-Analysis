# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
path = '/content/Web_Scrapped_websites.csv'
df = pd.read_csv(path, encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (9540, 31)

# %%
df.describe()
# Out:
#        Country_Rank    Reach_Day  Month_Average_Daily_Reach  Daily_Pageviews  \
# count   9540.000000  9478.000000                9495.000000      9478.000000
# mean      25.474843     3.222855                   3.209765         0.434900
# std       14.418225     8.647425                   8.428823         1.403890
# min        1.000000     0.000005                   0.000001         0.000000
# 25%       13.000000     0.013440                   0.014496         0.001248
# 50%       25.000000     0.310080                   0.282816         0.022752
# 75%       38.000000     1.699200                   1.859520         0.162240
# max       50.000000    42.604800                  41.149440         8.448960
#
#        Month_Average_Daily_Pageviews  Daily_Pageviews_per_user  \
# count                    9494.000000               9478.000000
# mean                        0.406529                  3.980859
# std                         1.300477                  2.927401
# ...

# %%
df.head()
# Out:
#    Country_Rank            Website Trustworthiness Avg_Daily_Visitors  \
# 0             1  www.google.com.af       Excellent                NaN
# 1             2     www.google.com       Excellent        515 007 350
# 2             3    www.youtube.com       Excellent        506 457 282
# 3             4   www.facebook.com       Excellent        270 071 255
# 4             5      www.yahoo.com       Excellent         99 572 035
#
#   Child_Safety Avg_Daily_Pageviews    Privacy Facebook_likes Twitter_mentions  \
# 0    Excellent                 NaN  Excellent              9                1
# 1    Excellent       4 192 159 833  Excellent          94.2K            11.2K
# 2    Excellent       2 679 159 025  Excellent          13.5K            16.5K
# 3         Good       1 082 985 733  Excellent          5.87M            64.4K
# 4    Excellent         383 352 336  Excellent          17.2K            1.11K
#
#   Google_pluses  ... Month_Average_Daily_Reach_percentage  \
# ...

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# Country_Rank                                   0
# Website                                        0
# Trustworthiness                                0
# Avg_Daily_Visitors                           144
# Child_Safety                                   0
# Avg_Daily_Pageviews                          144
# Privacy                                        0
# Facebook_likes                                 0
# Twitter_mentions                               0
# Google_pluses                                  0
# LinkedIn_mentions                              0
# Pinterest_pins                                 0
# StumbleUpon_views                              0
# Status                                         0
# Traffic_Rank                                   1
# Reach_Day                                     62
# Month_Average_Daily_Reach                     45
# Daily_Pageviews                               62
# Month_Average_Daily_Pageviews                 46
# ...

# %%
total_cells = np.product(df.shape)
total_missing = missing_values.sum()
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.2673294109690945

# %%
df.fillna(method='bfill', axis=0).fillna(0)
# Out:
#       Country_Rank                    Website Trustworthiness  \
# 0                1          www.google.com.af       Excellent
# 1                2             www.google.com       Excellent
# 2                3            www.youtube.com       Excellent
# 3                4           www.facebook.com       Excellent
# 4                5              www.yahoo.com       Excellent
# ...            ...                        ...             ...
# 9535            46  www.newsdzezimbabwe.co.uk         Unknown
# 9536            47       www.nehandaradio.com         Unknown
# 9537            48         www.mysagagame.com       Very poor
# 9538            49                 www.ntd.tv  Unsatisfactory
# 9539            50  www.emailaccessonline.com            Poor
#
#      Avg_Daily_Visitors Child_Safety Avg_Daily_Pageviews         Privacy  \
# 0           515 007 350    Excellent       4 192 159 833       Excellent
# ...

# %%
df["Avg_Daily_Visitors"].value_counts()
# Out:
# 118 921 355    191
# 506 457 282    190
# 270 071 255    188
# 99 572 035     179
# 56 576 433     158
#               ...
# 14 878           1
# 869              1
# 349              1
# 245 256          1
# 1 331 630        1
# Name: Avg_Daily_Visitors, Length: 3056, dtype: int64

# %%
numeric_data = df.select_dtypes(include='number')

# Heatmap showing the correlation matrix of numeric columns
sns.heatmap(data=numeric_data.corr(), annot=True)
plt.show()

# %%
dataexcel=pd.ExcelWriter('web.xlsx')
df.to_excel(dataexcel)
dataexcel.save()
# Out:
# <ipython-input-84-2cadbdacfd1d>:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   dataexcel.save()
